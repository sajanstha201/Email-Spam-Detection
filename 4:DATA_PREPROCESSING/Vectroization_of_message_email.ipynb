# %%
# !pip install transformers

# %%
import pandas as pd
import numpy as np
from transformers import BertTokenizer,TFBertModel
import tensorflow as tf
from sklearn.model_selection import train_test_split

# %% [markdown]
# FETCHING THE DATA FROM MY DRIVE

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data=pd.read_csv('/content/drive/MyDrive/Data Science/EMAIL SPAM DETECTION/DATA/cleaned_email_message_based.csv')
data
# Out:
#       spam                                            Message
# 0        0  Go until jurong point, crazy.. Available only ...
# 1        0                      Ok lar... Joking wif u oni...
# 2        1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3        0  U dun say so early hor... U c already then say...
# 4        0  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5566     1  This is the 2nd time we have tried 2 contact u...
# 5567     0               Will ü b going to esplanade fr home?
# 5568     0  Pity, * was in mood for that. So...any other s...
# 5569     0  The guy did some bitching but I acted like i'd...
# 5570     0                         Rofl. Its true to its name
#
# [5571 rows x 2 columns]

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-cased')
model = TFBertModel.from_pretrained("bert-base-cased")

# %%
vectorized=[]
for i in data['Message']:
  vector=model(tokenizer(i,return_tensors='tf',padding=True,truncation=True,max_length=256))['pooler_output'].numpy().reshape(-1)
  vectorized.append(vector)

# %%
print(np.array(vectorized).shape)
# Out:
# (5571, 768)

# %%
print(vectorized[0:2])

# %%
np.array(vectorized).shape
# Out:
# (5, 768)

# %%
np.save('/content/drive/MyDrive/Data Science/EMAIL SPAM DETECTION/DATA/vectorized_message_without_target.npy',vectorized)

# %%
gg=np.load('/content/drive/MyDrive/Data Science/EMAIL SPAM DETECTION/DATA/vectorized_message_without_target.npy')

# %%
l=[]
for i in range(len(data['spam'])):
  x=list(gg[i])
  x.append(data['spam'][i])
  l.append(x)

# %%
np.array(l).shape
# Out:
# (5571, 769)

# %%
np.save('/content/drive/MyDrive/Data Science/EMAIL SPAM DETECTION/DATA/vectorized_message_with_target.npy',l)
