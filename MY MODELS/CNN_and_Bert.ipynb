# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
v=np.array(np.load('/content/drive/MyDrive/Data Science/EMAIL SPAM DETECTION/DATA/vectorized_message_with_target.npy'))

# %%
v.shape
# Out:
# (5571, 769)

# %%
x=v[:,:-1]
y=v[:,-1]
y=y.reshape(-1,1)

# %%
print("x_shape: ",x.shape)
print("y_shape: ",y.shape)
# Out:
# x_shape:  (5571, 768)
# y_shape:  (5571, 1)

# %%
n_0=0
n_1=0
for i in y_train:
  if(i==0):
    n_0+=1
  if(i==1):
    n_1+=1
print('number of zero: ',n_0)
print('number of ones: ',n_1)
# Out:
# number of zero:  3855
# number of ones:  601

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
print("x_train shape: ",x_train.shape)
print('x_test shape: ',x_test.shape)
print("y_train shape: ",y_train.shape)
print("y_test shape: ",y_test.shape)
# Out:
# x_train shape:  (4456, 768)
# x_test shape:  (1115, 768)
# y_train shape:  (4456, 1)
# y_test shape:  (1115, 1)

# %%
model=tf.keras.models.Sequential([
    tf.keras.layers.Reshape((32,24,1),input_shape=(768,)),
    tf.keras.layers.Conv2D(8,(2,2),activation='relu'),
    tf.keras.layers.MaxPooling2D((2,2)),
    tf.keras.layers.Conv2D(4,(2,2),activation='relu'),
    tf.keras.layers.MaxPooling2D((2,2)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(14,activation='relu'),
    tf.keras.layers.Dense(1,activation='softmax')]
)
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %%
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  reshape_5 (Reshape)         (None, 32, 24, 1)         0
#
#  conv2d_15 (Conv2D)          (None, 31, 23, 8)         40
#
#  max_pooling2d_14 (MaxPooli  (None, 15, 11, 8)         0
#  ng2D)
#
#  conv2d_16 (Conv2D)          (None, 14, 10, 4)         132
#
#  max_pooling2d_15 (MaxPooli  (None, 7, 5, 4)           0
#  ng2D)
#
#  flatten_7 (Flatten)         (None, 140)               0
#
#  dense_14 (Dense)            (None, 14)                1974
#
#  dense_15 (Dense)            (None, 1)                 15
#
# ...
# Total params: 2161 (8.44 KB)
# Trainable params: 2161 (8.44 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history=model.fit(x_train,y_train,validation_data=(x_test,y_test),batch_size=32,epochs=100,verbose=1)

# %%
model2=tf.keras.models.Sequential([
    tf.keras.layers.Dense(768,input_shape=(768,),activation='linear'),
    tf.keras.layers.Dense(192,activation='linear'),
    tf.keras.layers.Dense(384,activation='linear'),
    tf.keras.layers.Dense(96,activation='linear'),
    tf.keras.layers.Dense(24,activation='linear'),
    tf.keras.layers.Dense(1,activation='softmax')]
)
model2.compile(
    optimizer='Adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %%
model2.fit(x_train,y_train,epochs=100)
# Out:
# Epoch 1/100
# 140/140 [==============================] - 3s 18ms/step - loss: 0.1374 - accuracy: 0.1349
# Epoch 2/100
# 140/140 [==============================] - 2s 11ms/step - loss: 0.1169 - accuracy: 0.1349
# Epoch 3/100
# 140/140 [==============================] - 2s 11ms/step - loss: 0.1045 - accuracy: 0.1349
# Epoch 4/100
# 140/140 [==============================] - 2s 11ms/step - loss: 0.0980 - accuracy: 0.1349
# Epoch 5/100
# 140/140 [==============================] - 2s 12ms/step - loss: 0.0846 - accuracy: 0.1349
# Epoch 6/100
# 140/140 [==============================] - 2s 11ms/step - loss: 0.0876 - accuracy: 0.1349
# Epoch 7/100
# 140/140 [==============================] - 2s 12ms/step - loss: 0.0766 - accuracy: 0.1349
# Epoch 8/100
# 140/140 [==============================] - 2s 17ms/step - loss: 0.0755 - accuracy: 0.1349
# Epoch 9/100
# 140/140 [==============================] - 2s 16ms/step - loss: 0.0705 - accuracy: 0.1349
# Epoch 10/100
# ...
